# %%
import json
import re

# %%
train_fn = "../data/negation_train.json"
dev_fn = "../data/negation_dev.json"
test_fn = "../data/negation_test.json"

# %% [markdown]
# ## What are the multi-word cues

# %%
mwcs = set()
for fn in [train_fn, dev_fn, test_fn]:
    with open(fn) as fh:
        for line in json.load(fh):
            if len(line["negations"]) > 0:
                for neg in line["negations"]:
                    if len(neg["Cue"][0]) > 1:
                        mwcs.add(tuple(neg["Cue"][0]))
mwcs
# Out:
# {('Verken', 'eller'),
#  ('har', 'til gode'),
#  ('hverken', 'eller'),
#  ('verken', 'eller')}

# %% [markdown]
# ## Affixal Cues

# %%
affixals = set()
affplus = set()
prefixes = set()
suffixes = set()
for fn in [train_fn, dev_fn, test_fn]:
    with open(fn) as fh:
        for line in json.load(fh):
            if len(line["negations"]) > 0:
                for neg in line["negations"]:
                    if neg["Affixal"]:
                        #if neg["Cue"][0][0] == "aldri" or neg["Cue"][0][0] == "ikke" or neg["Cue"][0][0] == "manglende":
                        #    print(line)
                        affixals.add(tuple(neg["Cue"][0]))
                        #print(neg["Cue"], neg["Scope"])
                        a,b = neg["Cue"][1][0].split(":")
                        a = int(a)
                        b = int(b)
                        # print(t[a-2:b+2])
                        if a - 1 > 0 and line["text"][a - 1] != " ":
                            c = a -1
                            # print(neg["Cue"], neg["Scope"])
                            while c > 0 and line["text"][c] != " ":
                                c -= 1
                            affplus.add((neg["Cue"][0][0], line["text"][c:b]))
                            suffixes.add(neg["Cue"][0][0])
                        else:
                            c = b
                            while c < len(line["text"]) and line["text"][c] != " ":
                                c += 1
                            affplus.add((neg["Cue"][0][0], line["text"][a:c]))
                            prefixes.add(neg["Cue"][0][0])
                        
affixals, affplus, prefixes, suffixes
# Out:
# ({('U',),
#   ('fri',),
#   ('frie',),
#   ('fritt',),
#   ('ikke-',),
#   ('in',),
#   ('løs',),
#   ('løse',),
#   ('løst',),
#   ('mis',),
#   ('tomme',),
#   ('u',),
#   ('utenom',)},
#  {('U', 'Ubeskjeden'),
#   ('U', 'Uendelig'),
#   ('U', 'Uengasjerende'),
#   ('U', 'Ujevn'),
#   ('U', 'Ujålete'),
#   ('U', 'Ukomplisert'),
#   ('U', 'Ulike'),
#   ('U', 'Unyansert'),
#   ('U', 'Uredigert'),
#   ('U', 'Usedvanlig'),
#   ('U', 'Uspennende'),
#   ('U', 'Usynlige'),
#   ('U', 'Utrettelig'),
#   ('U', 'Utro'),
#   ('U', 'Utrolig'),
#   ('U', 'Utvilsomt'),
#   ('U', 'Uvanlig'),
#   ('U', 'Uverdig'),
#   ('fri', ' bekymringsfri'),
#   ('fri', ' feilfri'),
#   ('fri', ' filterfri'),
#   ('fri', ' nøkkelfri'),
#   ('fri', ' rusfri'),
#   ('fri', ' voldsfri'),
#   ('frie', ' dialogfrie'),
#   ('frie', ' rusfrie'),
#   ('frie', ' vedlikeholdsfrie'),
#   ('fritt', ' bugfritt'),
#   ('ikke-', 'ikke-ideelle'),
#   ('ikke-', 'ikke-innvidde'),
#   ('ikke-', 'ikke-kosher-hovedretten'),
#   ('ikke-', 'ikke-låt'),
#   ('ikke-', 'ikke-produksjonsklart'),
#   ('ikke-', 'ikke-tema'),
#   ('ikke-', 'ikke-vestlig'),
#   ('in', 'ineffektiv'),
#   ('in', 'inkompatible'),
#   ('løs', ' bekymringsløs'),
#   ('løs', ' bunnløs'),
#   ('løs', ' endeløs'),
#   ('løs', ' fantasiløs'),
#   ('løs', ' fargeløs'),
#   ('løs', ' foreldreløs'),
#   ('løs', ' grenseløs'),
#   ('løs', ' hemningsløs'),
#   ('løs', ' hjelpeløs'),
#   ('løs', ' hjemløs'),
#   ('løs', ' hvileløs'),
#   ('løs', ' håpløs'),
#   ('løs', ' knappeløs'),
#   ('løs', ' kompromissløs'),
#   ('løs', ' lydløs'),
#   ('løs', ' maktesløs'),
#   ('løs', ' menigsløs'),
#   ('løs', ' meningsløs'),
#   ('løs', ' målløs'),
#   ('løs', ' poseløs'),
#   ('løs', ' pregløs'),
#   ('løs', ' rastløs'),
#   ('løs', ' retningsløs'),
#   ('løs', ' rotløs'),
#   ('løs', ' sanseløs'),
#   ('løs', ' smakløs'),
#   ('løs', ' sømløs'),
#   ('løs', ' tannløs'),
#   ('løs', ' temperamentsløs'),
#   ('løs', ' tidløs'),
#   ('løs', ' trådløs'),
#   ('løs', ' tøylesløs'),
#   ('løs', ' verdiløs'),
#   ('løs', ' vifteløs'),
#   ('løs', 'Endeløs'),
#   ('løs', 'Sømløs'),
#   ('løse', ' Fargeløse'),
#   ('løse', ' barnløse'),
#   ('løse', ' bunnløse'),
#   ('løse', ' endeløse'),
#   ('løse', ' fantasiløse'),
#   ('løse', ' forsvarsløse'),
#   ('løse', ' harmløse'),
#   ('løse', ' hemningsløse'),
#   ('løse', ' hensynsløse'),
#   ('løse', ' hjelmløse'),
#   ('løse', ' hjelpeløse'),
#   ('løse', ' hjerteløse'),
#   ('løse', ' håpløse'),
#   ('løse', ' karakterløse'),
#   ('løse', ' kompromissløse'),
#   ('løse', ' livløse'),
#   ('løse', ' meningsløse'),
#   ('løse', ' nådeløse'),
#   ('løse', ' rastløse'),
#   ('løse', ' retningsløse'),
#   ('løse', ' rotløse'),
#   ('løse', ' sanseløse'),
#   ('løse', ' sertifikatløse'),
#   ('løse', ' signaturløse'),
#   ('løse', ' sjelløse'),
#   ('løse', ' språkløse'),
#   ('løse', ' talentløse'),
#   ('løse', ' tankeløse'),
#   ('løse', ' tidløse'),
#   ('løse', ' trådløse'),
#   ('løse', ' verdiløse'),
#   ('løse', ' vergeløse'),
#   ('løse', ' åndeløse'),
#   ('løst', ' bunnløst'),
#   ('løst', ' energiløst'),
#   ('løst', ' følelsesløst'),
#   ('løst', ' hemningsløst'),
#   ('løst', ' humørløst'),
#   ('løst', ' håpløst'),
#   ('løst', ' kraftløst'),
#   ('løst', ' meningsløst'),
#   ('løst', ' nådeløst'),
#   ('løst', ' rastløst'),
#   ('løst', ' respektløst'),
#   ('løst', ' skamløst'),
#   ('løst', ' sorgløst'),
#   ('løst', ' sporløst'),
#   ('løst', ' sømløst'),
#   ('løst', 'Sorgløst'),
#   ('løst', 'Trådløst'),
#   ('mis', 'mislike'),
#   ('tomme', ' mennesketomme'),
#   ('u', 'uaktuelt'),
#   ('u', 'uambisiøs'),
#   ('u', 'uangripelig'),
#   ('u', 'uanstendig'),
#   ('u', 'uanstrengte'),
#   ('u', 'uappetittlige'),
#   ('u', 'uavhengig'),
#   ('u', 'uavklarte'),
#   ('u', 'ubalanse'),
#   ('u', 'ubalansert'),
#   ('u', 'ubarmhjertige'),
#   ('u', 'ubegrenset'),
#   ('u', 'ubegripelig'),
#   ('u', 'ubegripelige'),
#   ('u', 'ubegrunnet'),
#   ('u', 'ubehagelig'),
#   ('u', 'ubehagelige'),
#   ('u', 'ubehjelpelig'),
#   ('u', 'ubekveme'),
#   ('u', 'ubekvemt'),
#   ('u', 'uberegnelig'),
#   ('u', 'uberegnelige'),
#   ('u', 'uberørt'),
#   ('u', 'ubestemmelige'),
#   ('u', 'ubesudlet'),
#   ('u', 'ubetalelig'),
#   ('u', 'ubetalelige'),
#   ('u', 'ubetenksomt'),
#   ('u', 'ubetinget'),
#   ('u', 'ubetjent'),
#   ('u', 'ubetydelig'),
#   ('u', 'ubetydelige'),
#   ('u', 'ubrukelig'),
#   ('u', 'ubrukelige'),
#   ('u', 'ubrukt'),
#   ('u', 'ubudne'),
#   ('u', 'udelt'),
#   ('u', 'udetonerte'),
#   ('u', 'udiskutabelt'),
#   ('u', 'udiskutable'),
#   ('u', 'udødelig'),
#   ('u', 'udødelige'),
#   ('u', 'uelegant'),
#   ('u', 'uendelig'),
#   ('u', 'uendelige'),
#   ('u', 'uengasjert'),
#   ('u', 'uenig'),
#   ('u', 'uerfarne'),
#   ('u', 'ufarleg'),
#   ('u', 'ufarlig'),
#   ('u', 'ufattelig'),
#   ('u', 'ufattelige'),
#   ('u', 'uferdig'),
#   ('u', 'uferdige'),
#   ('u', 'ufiltrert'),
#   ('u', 'ufine'),
#   ('u', 'uflidde'),
#   ('u', 'ufokusert'),
#   ('u', 'ufordragelig'),
#   ('u', 'uforglemmelig'),
#   ('u', 'uforklarlige'),
#   ('u', 'uforløst'),
#   ('u', 'uforløste'),
#   ('u', 'uformell'),
#   ('u', 'uformelle'),
#   ('u', 'uforskammet'),
#   ('u', 'uforstyrrelig'),
#   ('u', 'uforståelig'),
#   ('u', 'uforståelige'),
#   ('u', 'ufortjent'),
#   ('u', 'uforutsigbar'),
#   ('u', 'uforutsigbart'),
#   ('u', 'ufrelste'),
#   ('u', 'ufrivillig'),
#   ('u', 'ufrivillige'),
#   ('u', 'ufullstendige'),
#   ('u', 'ufølsomme'),
#   ('u', 'ugifte'),
#   ('u', 'ugjenkallelig'),
#   ('u', 'ugjennomførbart'),
#   ('u', 'ugripelige'),
#   ('u', 'uheldige'),
#   ('u', 'uheldigste'),
#   ('u', 'uheldigvis'),
#   ('u', 'uhemmet'),
#   ('u', 'uhensiktsmessig'),
#   ('u', 'uhorvelige'),
#   ('u', 'uhyggelige'),
#   ('u', 'uhåndgripelige'),
#   ('u', 'uhøytidelige'),
#   ('u', 'uimotståelig'),
#   ('u', 'uimotståelige'),
#   ('u', 'uinspirert'),
#   ('u', 'uinspirerte'),
#   ('u', 'uintelligent'),
#   ('u', 'uinteressant'),
#   ('u', 'uinteressante'),
#   ('u', 'uinteresserte'),
#   ('u', 'ujevn'),
#   ('u', 'ujevne'),
#   ('u', 'ujevnheter'),
#   ('u', 'ujevnt'),
#   ('u', 'ujålete'),
#   ('u', 'ukarismatisk'),
#   ('u', 'ukjende'),
#   ('u', 'ukjent'),
#   ('u', 'ukjente'),
#   ('u', 'uklar'),
#   ('u', 'uklare'),
#   ('u', 'uklarheter'),
#   ('u', 'uklart'),
#   ('u', 'ukomplisert'),
#   ('u', 'ukonvensjonell'),
#   ('u', 'ukuelig'),
#   ('u', 'ulik'),
#   ('u', 'ulike'),
#   ('u', 'ulikt'),
#   ('u', 'ulovlig'),
#   ('u', 'ulovlige'),
#   ('u', 'ulykkelig'),
#   ('u', 'ulykkelige'),
#   ('u', 'uløyseleg'),
#   ('u', 'umenneskelig'),
#   ('u', 'umenneskelige'),
#   ('u', 'umerkbart'),
#   ('u', 'umerkelig'),
#   ('u', 'umettelige'),
#   ('u', 'umiskjennelig'),
#   ('u', 'umiskjennelige'),
#   ('u', 'umoden'),
#   ('u', 'umoderne'),
#   ('u', 'umodne'),
#   ('u', 'umorsom'),
#   ('u', 'umorsomme'),
#   ('u', 'umotiverte'),
#   ('u', 'umulig'),
#   ('u', 'umulige'),
#   ('u', 'umusikalsk'),
#   ('u', 'umælende'),
#   ('u', 'unaturlig'),
#   ('u', 'unekteleg'),
#   ('u', 'unektelig'),
#   ('u', 'unormalt'),
#   ('u', 'unorske'),
#   ('u', 'unødig'),
#   ('u', 'unødvendig'),
#   ('u', 'unødvendige'),
#   ('u', 'uoffisielt'),
#   ('u', 'uoppfinnsomt'),
#   ('u', 'uopphørlig'),
#   ('u', 'uoppmerksom'),
#   ('u', 'uorganisk'),
#   ('u', 'uoriginale'),
#   ('u', 'uortodoks'),
#   ('u', 'uortodokse'),
#   ('u', 'uoverkommelig'),
#   ('u', 'uoversiktlig'),
#   ('u', 'uoverskuelig'),
#   ('u', 'uovertruffen'),
#   ('u', 'uoverveid'),
#   ('u', 'upassende'),
#   ('u', 'upersonlige'),
#   ('u', 'upresis'),
#   ('u', 'upretensiøse'),
#   ('u', 'uproblematisk'),
#   ('u', 'uproffe'),
#   ('u', 'upåaktet'),
#   ('u', 'upåklagelig'),
#   ('u', 'upåmeldt'),
#   ('u', 'uredd'),
#   ('u', 'uregelmessig'),
#   ('u', 'uregjerlige'),
#   ('u', 'urett'),
#   ('u', 'urettferdig'),
#   ('u', 'urimelig'),
#   ('u', 'uro'),
#   ('u', 'uroen'),
#   ('u', 'urolig'),
#   ('u', 'urolige'),
#   ('u', 'uryddig'),
#   ('u', 'urørt'),
#   ('u', 'usagt'),
#   ('u', 'usagte'),
#   ('u', 'usannsynlig'),
#   ('u', 'usannsynlige'),
#   ('u', 'usedvanlig'),
#   ('u', 'usedvanlige'),
#   ('u', 'uselvisk'),
#   ('u', 'usentimental'),
#   ('u', 'usett'),
#   ('u', 'usigelig'),
#   ('u', 'usikker'),
#   ('u', 'usikkerhet'),
#   ('u', 'usikkert'),
#   ('u', 'usikre'),
#   ('u', 'usjenert'),
#   ('u', 'uskadd'),
#   ('u', 'uskarp'),
#   ('u', 'uskarpe'),
#   ('u', 'uskikkelige'),
#   ('u', 'uskyld'),
#   ('u', 'uskyldig'),
#   ('u', 'uskyldige'),
#   ('u', 'uslitelige'),
#   ('u', 'uslåelige'),
#   ('u', 'usmart'),
#   ('u', 'usminket'),
#   ('u', 'uspennende'),
#   ('u', 'ustabil'),
#   ('u', 'ustanselig'),
#   ('u', 'ustemt'),
#   ('u', 'ustoppelig'),
#   ('u', 'ustoppelige'),
#   ('u', 'ustraffet'),
#   ('u', 'ustyrlige'),
#   ('u', 'ustø'),
#   ('u', 'ustødig'),
#   ('u', 'usympatisk'),
#   ('u', 'usympatiske'),
#   ('u', 'usynlig'),
#   ('u', 'utallige'),
#   ('u', 'utenkelig'),
#   ('u', 'utidig'),
#   ('u', 'utilfredse'),
#   ('u', 'utilgjengelig'),
#   ('u', 'utillatelig'),
#   ('u', 'utiltalende'),
#   ('u', 'utradisjonelle'),
#   ('u', 'utrettelige'),
#   ('u', 'utro'),
#   ('u', 'utrolig'),
#   ('u', 'utrolige'),
#   ('u', 'utroverdig'),
#   ('u', 'utrulege'),
#   ('u', 'utrygg'),
#   ('u', 'utvilsomt'),
#   ('u', 'utydelig'),
#   ('u', 'utydelige'),
#   ('u', 'utypiske'),
#   ('u', 'utålmodig'),
#   ('u', 'uungåelige'),
#   ('u', 'uunngåelig'),
#   ('u', 'uutholdelige'),
#   ('u', 'uutslettelige'),
#   ('u', 'uuttalt'),
#   ('u', 'uvanleg'),
#   ('u', 'uvanlig'),
#   ('u', 'uvanlige'),
#   ('u', 'uvant'),
#   ('u', 'uvante'),
#   ('u', 'uvaskede'),
#   ('u', 'uvegerlig'),
#   ('u', 'uventa'),
#   ('u', 'uventede'),
#   ('u', 'uventet'),
#   ('u', 'uverdig'),
#   ('u', 'uvesentlige'),
#   ('u', 'uviktig'),
#   ('u', 'uviktige'),
#   ('u', 'uvitende'),
#   ('u', 'uvøren'),
#   ('u', 'uvørent'),
#   ('u', 'uvørneLandstrykeren'),
#   ('u', 'uønskede'),
#   ('u', 'uønsket'),
#   ('u', 'uønskete'),
#   ('utenom', 'utenomjordiske')},
#  {'U', 'ikke-', 'in', 'mis', 'u', 'utenom'},
#  {'fri', 'frie', 'fritt', 'løs', 'løse', 'løst', 'tomme'})

# %%
prefixes, suffixes
# Out:
# ({'U', 'ikke-', 'in', 'mis', 'u', 'utenom'},
#  {'fri', 'frie', 'fritt', 'løs', 'løse', 'løst', 'tomme'})

# %%
_, full_affix_negs = zip(*affplus)

# %%
prefixes = ['U', 'ikke-', 'in', 'mis', 'u', 'utenom']
suffixes = ['fri', 'frie', 'fritt', 'løs', 'løse', 'løst', 'tomme']
"^" + "|^".join(prefixes)
("$|".join(suffixes) + "$")
# Out:
# 'fri$|frie$|fritt$|løs$|løse$|løst$|tomme$'

# %% [markdown]
# ### Given a list of affixes, can we safely get the root?

# %%
for aff, fan in affplus:
    #print(aff, fan)
    pre = re.search(re.compile("^" + "|^".join(prefixes)), fan)
    suf = re.search(re.compile("$|".join(suffixes) + "$"), fan)
    #if pre is not None and pre.group(0) == aff and suf is not None:
    #    print("true prefix but also suffix: ", pre.group(0), suf.group(0), fan)
    #if suf is not None and suf.group(0) == aff and pre is not None:
    #    print("true suffix but also prefix: ", pre.group(0), suf.group(0), fan)
    x = "_"
    y = "_"
    if pre:
        x = pre.group(0)
        span = pre.span()
        #print(fan, span, fan[span[1]:])
    if suf:
        y = suf.group(0)
    #if not (x == "_" or y == "_"):
    print(aff, fan, x, y)
# Out:
# løs  endeløs _ løs
# ikke- ikke-vestlig ikke- _
# in ineffektiv in _
# u uforståelig u _
# u usikre u _
# u ubarmhjertige u _
# u utrettelige u _
# u ubekvemt u _
# U Uengasjerende U _
# løst  skamløst _ løst
# u ufokusert u _
# u ubestemmelige u _
# u uelegant u _
# u ubetalelig u _
# u uoppfinnsomt u _
# frie  rusfrie _ frie
# u uinteresserte u _
# u uklar u _
# frie  dialogfrie _ frie
# løst Trådløst _ løst
# u ufattelige u _
# u upåmeldt u _
# u ukjente u _
# u uvanleg u _
# løse  håpløse _ løse
# u uviktige u _
# u ukarismatisk u _
# u uungåelige u _
# u uoversiktlig u _
# u ubetenksomt u _
# u urørt u _
# u utydelige u _
# løse  tankeløse _ løse
# u uformelle u _
# løse  trådløse _ løse
# u utallige u _
# u uutholdelige u _
# u uforløst u løst
# u upresis u _
# u ugripelige u _
# u ubrukt u _
# u utilgjengelig u _
# løst  hemningsløst _ løst
# u ufrelste u _
# u uskikkelige u _
# løs  sømløs _ løs
# fri  rusfri _ fri
# u uavklarte u _
# u umulig u _
# u ufrivillige u _
# ikke- ikke-tema ikke- _
# u usynlig u _
# u uavhengig u _
# løs  temperamentsløs _ løs
# løse  sjelløse _ løse
# u uventede u _
# løst  energiløst _ løst
# u usminket u _
# u ustø u _
# u uproblematisk u _
# u ubetydelige u _
# u ufine u _
# løse  signaturløse _ løse
# løs  hvileløs _ løs
# u uoffisielt u _
# u uryddig u _
# u usett u _
# u uforklarlige u _
# fri  voldsfri _ fri
# u uventa u _
# u ulovlig u _
# u uhensiktsmessig u _
# løs  rastløs _ løs
# U Uvanlig U _
# u uvaskede u _
# løs  hjelpeløs _ løs
# u uregelmessig u _
# u uforutsigbar u _
# løs  hjemløs _ løs
# U Ulike U _
# u uvesentlige u _
# u uortodoks u _
# u uklarheter u _
# u ufattelig u _
# u uhøytidelige u _
# u uopphørlig u _
# løs  menigsløs _ løs
# løse  Fargeløse _ løse
# ikke- ikke-låt ikke- _
# u utilfredse u _
# løst  kraftløst _ løst
# u ubetalelige u _
# u upretensiøse u _
# U Uendelig U _
# u ufølsomme u _
# løse  talentløse _ løse
# u uventet u _
# løs  hemningsløs _ løs
# U Uredigert U _
# u urimelig u _
# løs  kompromissløs _ løs
# u ugjennomførbart u _
# løse  hemningsløse _ løse
# u uredd u _
# u ulykkelig u _
# u ubrukelig u _
# u urolige u _
# u usikkerhet u _
# u uoverskuelig u _
# ikke- ikke-ideelle ikke- _
# u uoriginale u _
# u ulik u _
# u upassende u _
# u uheldigvis u _
# u ufordragelig u _
# u udødelige u _
# u utålmodig u _
# u uutslettelige u _
# løse  hjelmløse _ løse
# u uovertruffen u _
# u umulige u _
# løs  målløs _ løs
# u uinteressant u _
# u uvante u _
# u uforløste u _
# løse  hensynsløse _ løse
# u ubehjelpelig u _
# løse  fantasiløse _ løse
# u ustemt u _
# fri  nøkkelfri _ fri
# u ukuelig u _
# u urettferdig u _
# løse  karakterløse _ løse
# ikke- ikke-produksjonsklart ikke- _
# u uimotståelige u _
# u uskadd u _
# u uheldigste u _
# u uhyggelige u _
# løs  fantasiløs _ løs
# u ujevnt u _
# u uvørneLandstrykeren u _
# u uimotståelig u _
# løst  rastløst _ løst
# u uklart u _
# u urolig u _
# u ufrivillig u _
# u umotiverte u _
# u ubesudlet u _
# frie  vedlikeholdsfrie _ frie
# u umælende u _
# u udødelig u _
# fri  filterfri _ fri
# u uintelligent u _
# u uendelig u _
# u utro u _
# løst  følelsesløst _ løst
# u uskyldige u _
# løst  respektløst _ løst
# u udetonerte u _
# u uformell u _
# løse  vergeløse _ løse
# U Unyansert U _
# løse  bunnløse _ løse
# løst  bunnløst _ løst
# u udelt u _
# u ufiltrert u _
# U Utrolig U _
# løs  lydløs _ løs
# u ubetinget u _
# u utradisjonelle u _
# løs  bunnløs _ løs
# u uaktuelt u _
# u ujevne u _
# u utrolig u _
# u umusikalsk u _
# u uoverveid u _
# u ubekveme u _
# løst  humørløst _ løst
# løs  håpløs _ løs
# u uønskede u _
# u uanstrengte u _
# u uorganisk u _
# u ustabil u _
# løs  rotløs _ løs
# u utroverdig u _
# u umerkelig u _
# u usedvanlig u _
# u uberørt u _
# u usympatisk u _
# u utrygg u _
# u udiskutabelt u _
# løse  sanseløse _ løse
# løse  nådeløse _ løse
# U Ujevn U _
# løse  verdiløse _ løse
# fritt  bugfritt _ fritt
# u uinteressante u _
# u uverdig u _
# u utypiske u _
# u uferdig u _
# u ulike u _
# u uforglemmelig u _
# u upåklagelig u _
# u uslitelige u _
# u uroen u _
# u ustraffet u _
# u ubegripelig u _
# u utrulege u _
# u uunngåelig u _
# løse  rotløse _ løse
# u ustanselig u _
# u uforutsigbart u _
# løse  åndeløse _ løse
# u uvitende u _
# u ufarleg u _
# u usmart u _
# u upåaktet u _
# u utenkelig u _
# U Utvilsomt U _
# løs  knappeløs _ løs
# u unødvendige u _
# løs  tidløs _ løs
# løst  sømløst _ løst
# u uvøren u _
# u uoverkommelig u _
# u umoderne u _
# u usigelig u _
# u uønskete u _
# u ubrukelige u _
# u usagte u _
# u ustoppelige u _
# u utrolige u _
# løs  retningsløs _ løs
# u ustyrlige u _
# løse  hjerteløse _ løse
# u ubehagelig u _
# u utillatelig u _
# u urett u _
# u uferdige u _
# løs  tøylesløs _ løs
# løs  vifteløs _ løs
# u ujålete u _
# u uro u _
# u ukomplisert u _
# u uvant u _
# fri  bekymringsfri _ fri
# løs  smakløs _ løs
# u ugifte u _
# u uortodokse u _
# u unorske u _
# u unaturlig u _
# u ufortjent u _
# u uvørent u _
# u usagt u _
# ikke- ikke-kosher-hovedretten ikke- _
# u uambisiøs u _
# u usentimental u _
# u usannsynlig u _
# u umettelige u _
# u uforskammet u _
# u uhorvelige u _
# løse  sertifikatløse _ løse
# U Utro U _
# u umodne u _
# løse  livløse _ løse
# u umiskjennelig u _
# løst  håpløst _ løst
# u uvanlige u _
# u uflidde u _
# u uappetittlige u _
# u uendelige u _
# u utidig u _
# løse  endeløse _ løse
# løs  foreldreløs _ løs
# u uenig u _
# u uinspirert u _
# u usedvanlige u _
# løst Sorgløst _ løst
# u usympatiske u _
# u ubudne u _
# U Ujålete U _
# u uberegnelig u _
# u udiskutable u _
# løse  språkløse _ løse
# u uklare u _
# U Utrettelig U _
# løs  pregløs _ løs
# u uskarpe u _
# løs  bekymringsløs _ løs
# fri  feilfri _ fri
# mis mislike mis _
# løs Endeløs _ løs
# U Ubeskjeden U _
# u uspennende u _
# u ustødig u _
# u upersonlige u _
# u uhåndgripelige u _
# u ubalanse u _
# løse  retningsløse _ løse
# løs Sømløs _ løs
# u uproffe u _
# u ukjende u _
# løs  maktesløs _ løs
# u usikkert u _
# u uuttalt u _
# løst  nådeløst _ løst
# løs  verdiløs _ løs
# u uforstyrrelig u _
# in inkompatible in _
# u umorsom u _
# u unødig u _
# u usjenert u _
# løse  forsvarsløse _ løse
# u uoppmerksom u _
# løse  tidløse _ løse
# løse  meningsløse _ løse
# u ujevn u _
# løs  sanseløs _ løs
# u ubegrenset u _
# u ubalansert u _
# u utvilsomt u _
# løst  sporløst _ løst
# løst  sorgløst _ løst
# u uanstendig u _
# u unekteleg u _
# løs  fargeløs _ løs
# u ubetydelig u _
# løse  harmløse _ løse
# tomme  mennesketomme _ tomme
# u ukjent u _
# u ubehagelige u _
# u utydelig u _
# u unektelig u _
# u ubegripelige u _
# u ubetjent u _
# u uløyseleg u _
# u uhemmet u _
# løs  trådløs _ løs
# løse  rastløse _ løse
# u ulovlige u _
# løs  poseløs _ løs
# u unormalt u _
# u umiskjennelige u _
# u uskyld u _
# U Usynlige U _
# u uslåelige u _
# u ugjenkallelig u _
# løs  meningsløs _ løs
# U Ukomplisert U _
# u umenneskelige u _
# u ustoppelig u _
# utenom utenomjordiske u _
# u usannsynlige u _
# løse  kompromissløse _ løse
# U Uverdig U _
# løse  hjelpeløse _ løse
# u uangripelig u _
# u ulikt u _
# u uønsket u _
# u ufarlig u _
# u unødvendig u _
# u uengasjert u _
# løs  tannløs _ løs
# u uskyldig u _
# u ujevnheter u _
# u umenneskelig u _
# u umorsomme u _
# u usikker u _
# U Usedvanlig U _
# løst  meningsløst _ løst
# u uerfarne u _
# U Uspennende U _
# u uvegerlig u _
# u uskarp u _
# u utiltalende u _
# u umoden u _
# u ubegrunnet u _
# u uforståelige u _
# løs  grenseløs _ løs
# u uregjerlige u _
# u ulykkelige u _
# løse  barnløse _ løse
# ikke- ikke-innvidde ikke- _
# u uberegnelige u _
# u uvanlig u _
# u uselvisk u _
# u uheldige u _
# u ukonvensjonell u _
# u ufullstendige u _
# u uviktig u _
# u umerkbart u _
# u uinspirerte u _

# %% [markdown]
# #### How many affixes are there in train, dev, test

# %%
from collections import Counter
for fn in [train_fn, dev_fn, test_fn]:
    cnt = Counter()
    with open(fn) as fh:
        for line in json.load(fh):
            next_sen = False
            if len(line["negations"]) > 0:
                for neg in line["negations"]: 
                    for cue in neg["Cue"][0]:
                        if cue in prefixes or cue in suffixes:
                            #print(fn, cue)
                            #print(line)
                            cnt[cue] += 1
                            next_sen = True
                            break
                    if next_sen:
                        break
    print(cnt)
# Out:
# Counter({'u': 349, 'løs': 33, 'løst': 26, 'løse': 25, 'U': 16, 'fri': 7, 'ikke-': 5, 'frie': 3, 'utenom': 2, 'in': 1, 'tomme': 1, 'mis': 1})
# Counter({'u': 56, 'løse': 11, 'løs': 7, 'U': 5, 'løst': 3, 'ikke-': 1})
# Counter({'u': 51, 'løs': 5, 'løse': 2, 'løst': 2, 'fri': 1, 'U': 1})

# %% [markdown]
# #### Count all tyypes of cues

# %%
from collections import Counter
cues = set()
cs = []
for fn in [train_fn, dev_fn, test_fn]:
    cnt = Counter()
    with open(fn) as fh:
        for line in json.load(fh):
            next_sen = False
            if len(line["negations"]) > 0:
                for neg in line["negations"]: 
                    for cue in neg["Cue"][0]:
                        cnt[(cue, neg["Affixal"])] += 1
                        next_sen = True
                        break
                    if next_sen:
                        break
    #print(set(cnt.keys()))
    cs.append(cnt.keys())
    cues.update(cnt.keys())

# %% [markdown]
# ### When using pre-defined affixes these cues need to be saved

# %%
bad = []
for fan, is_aff in cues:
    pre = re.search(re.compile("^" + "|^".join(prefixes)), fan)
    suf = re.search(re.compile("$|".join(suffixes) + "$"), fan)
    x = "_"
    y = "_"
    if pre:
        x = pre.group(0)
        span = pre.span()
        #print(fan, span, fan[span[1]:])
    if suf:
        y = suf.group(0)
    #if not (x == "_" or y == "_"):
    if is_aff and (suf or pre):
        pass
        #print("good boy: ", fan, x, y)
    elif not is_aff and (suf or pre):
        print("bad boy: ", fan, x, y)
        bad.append(fan)
# Out:
# bad boy:  inget in _
# bad boy:  utan u _
# bad boy:  Unntaket U _
# bad boy:  uten u _
# bad boy:  fri _ fri
# bad boy:  inga måter in _
# bad boy:  ingen in _
# bad boy:  Uten U _
# bad boy:  ingenting in _
# bad boy:  uteblir u _
# bad boy:  unntak u _
# bad boy:  mistet mis _
# bad boy:  unntatt u _
# bad boy:  mister mis _
# bad boy:  uteble u _
# bad boy:  unngår u _
# bad boy:  unntaket u _
# bad boy:  ingen måte in _
# bad boy:  unngå u _
# bad boy:  intet in _

# %% [markdown]
# ### Which cues are present in Dev/Test but not Train

# %%
cs = [[x for x,_ in c] for c in cs]

# %%
tr, de, te = cs
tr = set(tr)
de = set(de)
te = set(te)

# %% [markdown]
# #### Dev but not train

# %%
de - tr
# Out:
# {'Mangelen', 'bort', 'mangle', 'motsetning', 'uteble'}

# %% [markdown]
# #### Test but not train

# %%
te - tr
# Out:
# {'fravær', 'fraværet', 'inget', 'mistet', 'null', 'savnet', 'strippet'}

# %% [markdown]
# ## Bug hunt
#
# Transforming the json- and point-to-root formats to starsem should yield the same results.
# It does not but why?

# %%
def get_neg_cols(s):
    cols = []
    for t in s:
        nc = sorted([tuple(t[7:][i:i+3]) for i in range(0, len(t[7:]), 3)])
        # print(nc)
        cols.append(nc)
    return cols

# %%
def read_sen(lines):
    ss = []
    s = []
    for line in lines:
        line = line.strip().split("\t")
        if len(line) <= 1:
            ss.append(s)
            s = []
        else:
            s.append(line)
    return ss

# %%
def compare_starsems(ss1, ss2):
    for s1, s2 in zip(ss1, ss2):
        if len(s1[0]) > 8:
            n1 = get_neg_cols(s1)
            n2 = get_neg_cols(s2)
            # print(n1, n2)
            if n1 != n2:
                for c1, c2 in zip(n1, n2):
                    if c1 != c2:
                        print(s1[0][1],c1, c2)
                    pass

# %% [markdown]
# ### Differences between json and ptr for train, dev & test

# %%
for x in ["train", "dev", "test"]:
    starsem = open(f"neg_{x}.starsem").readlines()
    ptr = open(f"ptr_{x}.starsem").readlines()
    ss1 = read_sen(starsem)
    ss2 = read_sen(ptr)
    print(x)
    compare_starsems(ss1, ss2)
    print()
# Out:
# train
# 101554-08-01 [('u', '_', '_')] [('u', 'trolig', '_')]
# 701363-10-07 [('u', '_', '_')] [('u', 'musikalsk', '_')]
# 003803-21-02 [('u', '_', '_')] [('u', 'påklagelig', '_')]
# 200099-11-01 [('_', 'knappeløs', '_'), ('løs', '_', '_')] [('_', 'knappeløs', '_'), ('løs', 'knappe', '_')]
# 202043-05-01 [('Ikke', '_', '_')] [('skjermIkke', '_', '_')]
# 202043-05-01 [('_', 'elegant', '_')] [('_', 'elegantKresent', '_')]
# 301338-06-01 [('_', '_', '_'), ('_', '_', '_'), ('u', '_', '_')] [('_', '_', '_'), ('_', '_', '_'), ('u', 'sikker', '_')]
# 111141-01-01 [('løst', '_', '_')] [('løst', 'håp', '_')]
# 107326-04-02 [('_', '_', '_'), ('mangler', 'mangler', '_')] [('_', '_', '_'), ('mangler', '_', '_')]
# 111170-03-03 [('_', '_', '_'), ('_', 'o', '_')] [('_', '_', '_'), ('_', 'ok', '_')]
# 100866-06-01 [('u', '_', '_')] [('u', 'ventede', '_')]
# 001670-05-03 [('u', '_', '_')] [('u', 'vanleg', '_')]
# 001965-06-02 [('_', '_', '_'), ('_', 'dop', '_')] [('_', '_', '_'), ('_', 'dop.', '_')]
# 500043-20-04 [('Ingen', 'Ingen', '_')] [('Ingen', '_', '_')]
# 500043-20-06 [('Ingen', 'Ingen', '_'), ('_', '_', '_')] [('Ingen', '_', '_'), ('_', '_', '_')]
# 500043-20-06 [('_', '_', '_'), ('ingen', 'ingen', '_')] [('_', '_', '_'), ('ingen', '_', '_')]
# 100183-06-01 [('_', '_', '_'), ('_', 'en', '_')] [('_', 'en', '_'), ('_', 'en', '_')]
# 201835-23-02 [('_', '50.', '_')] [('_', '50.Kamerasnarvei', '_')]
#
# dev
# 602282-02-03 [('_', 'det', '_')] [('_', 'det.Her', '_')]
#
# test
# 301662-05-03 [('løs', '_', '_')] [('løs', 'kompromiss', '_')]

# %% [markdown]
# `
# train
#
# **affix is handled regularly in ptr but has an empty scope according to json**
#
# 108182-03-05 [('u', '\_', '\_')] [('u', 'tvilsomt', '\_')]
#
# 101554-08-01 [('u', '\_', '\_')] [('u', 'trolig', '\_')]
#
# 701363-10-07 [('u', '\_', '\_')] [('u', 'musikalsk', '\_')]
#
# 003803-21-02 [('u', '\_', '\_')] [('u', 'påklagelig', '\_')]
#
# 200099-11-01 [('\_', 'knappeløs', '\_'), ('løs', '\_', '\_')] [('\_', 'knappeløs', '\_'), ('løs', 'knappe', '\_')]
#
# **there is no whitespace in the string but the annotation in json fixes that (only in (cue/scope)**
#
# 202043-05-01 [('Ikke', '\_', '\_')] [('skjermIkke', '\_', '\_')]
#
# 202043-05-01 [('\_', 'elegant', '\_')] [('\_', 'elegantKresent', '\_')]
#
# **affix is handled regularly in ptr but has an empty scope according to json**
#
# 301338-06-01 [('\_', '\_', '\_'), ('\_', '\_', '\_'), ('u', '\_', '\_')] [('\_', '\_', '\_'), ('\_', '\_', '\_'), ('u',
# 'sikker', '\_')]
#
# 111141-01-01 [('løst', '\_', '\_')] [('løst', 'håp', '\_')]
#
#
# dev
#
# **there is no whitespace in the string but the annotation in json fixes that (only in (cue/scope)**
#
# 602282-02-03 [('\_', 'det', '\_')] [('\_', 'det.Her', '\_')]
#
#
# test
#
# **affix is handled regularly in ptr but has an empty scope according to json**
#
# 301662-05-03 [('løs', '\_', '\_')] [('løs', 'kompromiss', '\_')]`
